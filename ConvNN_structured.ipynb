# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda
import pandas as pd
import os
import torch.optim as optim

# %%
train_data = datasets.FashionMNIST(root = "data" , train = True, download = True, transform = ToTensor(), target_transform= Lambda( lambda y: torch.zeros(10, dtype= torch.float).scatter_(0,torch.tensor(y),value = 1)))
test_data = datasets.FashionMNIST(root = "data" , train = False, download = True, transform = ToTensor(), target_transform= Lambda( lambda y: torch.zeros(10, dtype= torch.float).scatter_(0,torch.tensor(y),value = 1)))
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %%
train_dataloader = DataLoader( dataset= train_data, batch_size = 64, shuffle = True)
test_dataloader = DataLoader( dataset= test_data, batch_size = 64, shuffle = True)

# %%
# Defining activation and loss functions

#relu class
class relu_activation(object):
  
  #relu
  def activate(self,z):
    zero= torch.zeros_like(z)
    return torch.maximum(zero, z)
  

  #Element-wise Heaviside theta function definition
  def activate_prime(self,z):
    zz= z.clone()
    size = torch.tensor(zz.size()).prod() #total size of input tensor
    z2 = zz.reshape(size)  #flattaning input tensor
    for elem in range(size):  #Taking the derivative element-wise
      if z2[elem] > 0:
       z2[elem]=1
      else: z2[elem] = 0

    out = z2.reshape(torch.tensor(zz.size()).tolist())  #reshaping relu derivative back to original tensor shape
    return out


#Softmax
class softmax_activation(object):

  def activate(self, z):
    out = torch.exp(z)
    norm = out.sum()
    return out/norm

  def activate_prime(self, z):
    return torch.ones_like(z)    #Since softmax is used only for the final layer, I have included the softmax derivative in the derivative of the loss function for convenience


#Using KL divergence of softmax activations
def loss_fn_prime(xx,yy):
  return xx-yy

# %%
# connected layer class
class Connected(object):
  def __init__(self, tensor_shape, activation_fn=None):
    #tensor_shape = list of tensor dimensions of connected layer (dim =0 is output)
    self.activation_fn = activation_fn
    self.shape = tensor_shape
    self.input_size = ((torch.tensor(tensor_shape)).prod())/tensor_shape[0]

    self.weight = torch.randn(tuple(tensor_shape))/torch.sqrt(self.input_size)
    self.bias = torch.randn(tensor_shape[0])

    self.dbias = torch.zeros_like(self.bias)
    self.dweight = torch.zeros_like(self.weight)


  def zero_derivative(self):
    self.dbias = torch.zeros_like(self.bias)
    self.dweight = torch.zeros_like(self.weight)


  def update(self, learning_rate, batch_size):
    bias_update = self.dbias.clone()
    weight_update = self.dweight.clone()
    self.bias -= bias_update *(learning_rate / batch_size)
    self.weight -= weight_update *(learning_rate / batch_size)




  def set_input(self, inp):
    self.input = inp
    self.preact = torch.tensordot(self.weight, inp, dims = len(self.shape)-1) + self.bias
    if self.activation_fn:
      self.activ = self.activation_fn.activate(self.preact)
    else: self.activ= self.preact



  def backward(self, delta):
    if self.activation_fn:
      delta_new = delta * self.activation_fn.activate_prime(self.preact)
    else: delta_new = delta

    self.dbias += delta_new
    self.dweight += torch.tensordot(delta_new, self.input, dims =0 )
    delta_new = torch.tensordot(delta_new, self.weight, dims = ([0],[0]))
    return delta_new

# %%
#convolutional-pooling layer class
class ConvPool(object):
  
  def __init__(self, image_shape, filter_shape, pooling_shape, activation_fn=None):
    #image_shape = list of dims of input image (feature_num x image_size x image_size)
    #filter_shape = list of convolution filter dimensions (feature_num_out x feature_num_inp x resolution x resolution)
    self.activation_fn = activation_fn

    self.filter_shape = filter_shape
    self.image_shape = image_shape 
    self.pooling_shape = pooling_shape

    self.convolution_size = ( int(image_shape[1]- filter_shape[2] +1) , int(image_shape[2]- filter_shape[3] +1) )
    self.output_size = ( int( (image_shape[1]- filter_shape[2] +1)/pooling_shape[0]), int( (image_shape[2]- filter_shape[3] +1)/pooling_shape[1]) )
    
    self.weight = torch.randn(tuple(filter_shape))/(torch.sqrt(torch.tensor(filter_shape[1]*filter_shape[2]*filter_shape[3])))
    self.bias = torch.tensordot( torch.randn(filter_shape[0]), torch.ones(self.output_size), dims=0 )

    self.dbias = torch.zeros_like(self.bias)
    self.dweight = torch.zeros_like(self.weight)
    
    #initiating convolutional and pooling isometries
    self.conv_isometry = torch.zeros(self.convolution_size[0] , self.convolution_size[1], filter_shape[2], filter_shape[3], image_shape[1], image_shape[2])
    self.pool_isometry= torch.zeros(filter_shape[0], self.output_size[0], self.output_size[1], filter_shape[0], self.convolution_size[0], self.convolution_size[1]) 


    #loop defining the convolution isometry 
    for a in range(self.convolution_size[0]):
      for b in range(self.convolution_size[1]):
        for i in range( int(filter_shape[2]) ):
          for j in range( int(filter_shape[3]) ):
            self.conv_isometry[a,b,i,j,a+i, b+j] = 1




  def zero_derivative(self):
    self.dbias = torch.zeros_like(self.bias)
    self.dweight = torch.zeros_like(self.weight)


  def update(self, learning_rate, batch_size):
    bias_update = self.dbias.clone()
    weight_update = self.dweight.clone()
    self.bias -= bias_update *(learning_rate / batch_size)
    self.weight -= weight_update *(learning_rate / batch_size)




  
  def set_input(self, inp):
    self.input = torch.tensordot(inp, self.conv_isometry, dims= ([1,2],[4,5]))  #5-tensor (input_feature_num x filter_num x filter_num x resolution x resolution)
    act_int = torch.tensordot(self.weight, self.input, dims= ([1,2,3],[0,3,4]))   #3-tensor (output_num x filter_num x filter_num) 
    
    #loop for constructing pooling isometry tensor 
    for k in range(int(self.filter_shape[0])):
      for i in range(int(self.output_size[0])):
        for j in range(int(self.output_size[1])):
          maxim = torch.argmax(act_int[k, int(self.pooling_shape[0])*i: int(self.pooling_shape[0])*(i+1), int(self.pooling_shape[1])*j: int(self.pooling_shape[1])*(j+1)]).item() #selecting maximum element in every pooling window
          self.pool_isometry[k, i , j , k , int(self.pooling_shape[0])*i + int(maxim/self.pooling_shape[1]) , int(self.pooling_shape[1])*j + (maxim % self.pooling_shape[1])] = 1

    self.preact = torch.tensordot(self.pool_isometry, act_int, dims = 3) + self.bias
    if self.activation_fn:
      self.activ = self.activation_fn.activate(self.preact)
    else: self.activ= self.preact 




  def backward(self, delta):
    if self.activation_fn:
      delta_new = delta * self.activation_fn.activate_prime(self.preact)
    else: delta_new = delta
    
    self.dbias += torch.tensordot( torch.sum(delta_new, dim = (1,2)), torch.ones(self.output_size), dims=0 )
    
    delta_new = torch.tensordot(delta_new, self.pool_isometry, dims=([0,1,2],[0,1,2]))  #3-tensor (output_feature_num x filter_num x filter_num)
    self.dweight += torch.tensordot(delta_new , self.input, dims=([1,2],[1,2]))  #4-tensor (output_feature_num x input_feature_num x resolution x resolution)


    delta_new = torch.tensordot(delta_new, self.weight, dims=([0],[0]))  #5-tensor (filter_num x filter_num x input_feature_num x resolution x resolution))
    delta_new = torch.tensordot(delta_new, self.conv_isometry, dims = ([0,1,3,4],[0,1,2,3]))  #3-tensor (input_feature_num x input_size x input_size) undoing convolution isometry to map delta back to the activation space of the previous convolutional layer

    return delta_new

# %%
class Network(object):
  def __init__(self, layers):
    self.layers = layers


#--------------Stochastic gradient descent---------------------
  def grad_desc(self, train_data, lr, epochs, test_data=None):

    for epoch in range(epochs):
      dataloader_iter = train_data
      random= torch.randint(0,850,(1,)).item()
      for batch, (X,y) in enumerate(dataloader_iter):
        batch_size = len(X)
        if (batch>random) & (batch<(random+30)):
          for k in range(batch_size):
            self.backprop(X[k],y[k])
          for layer in self.layers:
            layer.update(lr, batch_size)
            print(f"{(torch.min(layer.dweight)*lr/batch_size, torch.max(layer.dweight)*lr/batch_size)}  {(torch.min(layer.dbias)*lr/batch_size, torch.max(layer.dbias)*lr/batch_size) }\n" )
            print(f"{(torch.min(layer.weight), torch.max(layer.weight))}  {(torch.min(layer.bias), torch.max(layer.bias)) }\n" )
            layer.zero_derivative()
            print(f"{(torch.min(layer.dweight), torch.max(layer.dweight))}  {(torch.min(layer.dbias), torch.max(layer.dbias)) }\n\n" )
          print(f"Minibatch {batch} complete \n\n")
      print(f"Epoch {epoch} complete!\n\n")
      
      if test_data:
        test_iter= test_data
        acurracy=0
        number = 0
        for batcht, (Xt, yt) in enumerate(test_iter):
          if (batcht < 10):
            for k in range(len(Xt)):
             out = self.feedforward(Xt[k])
             out_pred = torch.argmax(out)
             out_true = torch.argmax(yt[k])
             number+=1
             if (out_pred == out_true):
               acurracy += 1
            print(f"Epoch {epoch} minibatch {batcht} achieved accuracy {acurracy/number}")


#--------------backpropagation method---------------------
  def backprop(self,x,y):
    out = self.feedforward(x)

    delta = loss_fn_prime(out, y) 

    for k in range(len(self.layers)):
      delta = self.layers[-k-1].backward(delta)

           

#---------------feedforward method---------------------
  def feedforward(self, x):
    inp = x
    for layer in self.layers:
      layer.set_input(inp)
      inp = layer.activ
    return inp

# %%
model= Network([ConvPool([1,28,28],[15,1, 5, 5], [2,2], relu_activation()) , ConvPool([15,12,12],[15, 15, 5, 5], [2,2], relu_activation()) , Connected([100,15,4,4], relu_activation()) , Connected([10, 100], softmax_activation()) ])

# %%
model.grad_desc(train_dataloader, 0.04, 5, test_data = test_dataloader)
# Out:
# (tensor(-0.0176), tensor(0.0185))  (tensor(-0.0109), tensor(0.0098))
#
# (tensor(-0.5625), tensor(0.5521))  (tensor(-2.1584), tensor(1.3059))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0638), tensor(0.0642))  (tensor(-0.0048), tensor(0.0041))
#
# (tensor(-0.2021), tensor(0.2063))  (tensor(-0.3865), tensor(1.9883))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0363), tensor(0.0432))  (tensor(-0.0029), tensor(0.0037))
#
# (tensor(-0.3261), tensor(0.2396))  (tensor(-2.4113), tensor(1.7104))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0305), tensor(0.0736))  (tensor(-0.0045), tensor(0.0107))
#
# (tensor(-0.3020), tensor(0.3738))  (tensor(-1.6481), tensor(1.9002))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 694 complete
#
#
# (tensor(-0.0116), tensor(0.1624))  (tensor(-0.0045), tensor(0.0836))
#
# (tensor(-0.6434), tensor(0.4909))  (tensor(-2.1577), tensor(1.2481))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0233), tensor(0.1509))  (tensor(-0.0007), tensor(0.0118))
#
# (tensor(-0.2021), tensor(0.1992))  (tensor(-0.3865), tensor(1.9883))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.2800), tensor(0.2234))  (tensor(-0.0062), tensor(0.0051))
#
# (tensor(-0.3055), tensor(0.3216))  (tensor(-2.4113), tensor(1.7104))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.2273), tensor(0.6472))  (tensor(-0.0074), tensor(0.0215))
#
# (tensor(-0.6441), tensor(0.4157))  (tensor(-1.6696), tensor(1.9033))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 695 complete
#
#
# (tensor(-0.0254), tensor(0.0657))  (tensor(-0.0085), tensor(0.0343))
#
# (tensor(-0.6502), tensor(0.5145))  (tensor(-2.1504), tensor(1.2137))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0159), tensor(0.0941))  (tensor(-0.0034), tensor(0.0344))
#
# (tensor(-0.2021), tensor(0.1972))  (tensor(-0.3831), tensor(1.9791))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0089), tensor(0.0223))  (tensor(-0.0044), tensor(0.0119))
#
# (tensor(-0.3055), tensor(0.3216))  (tensor(-2.4113), tensor(1.7118))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0385), tensor(0.1571))  (tensor(-0.0050), tensor(0.0238))
#
# (tensor(-0.6425), tensor(0.4159))  (tensor(-1.6646), tensor(1.9056))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 696 complete
#
#
# (tensor(-0.0020), tensor(0.0497))  (tensor(-0.0011), tensor(0.0161))
#
# (tensor(-0.6507), tensor(0.4805))  (tensor(-2.1666), tensor(1.2121))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0120), tensor(0.0340))  (tensor(-0.0018), tensor(0.0059))
#
# (tensor(-0.2021), tensor(0.1968))  (tensor(-0.3890), tensor(1.9777))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0082), tensor(0.0099))  (tensor(-0.0031), tensor(0.0033))
#
# (tensor(-0.3055), tensor(0.3216))  (tensor(-2.4113), tensor(1.7095))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0146), tensor(0.0159))  (tensor(-0.0055), tensor(0.0074))
#
# (tensor(-0.6394), tensor(0.4159))  (tensor(-1.6602), tensor(1.9054))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 697 complete
#
#
# (tensor(-0.0064), tensor(0.0014))  (tensor(-0.0030), tensor(0.0010))
#
# (tensor(-0.6512), tensor(0.4797))  (tensor(-2.1666), tensor(1.2120))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0072), tensor(0.0041))  (tensor(-0.0057), tensor(0.0127))
#
# (tensor(-0.2021), tensor(0.1958))  (tensor(-0.3869), tensor(1.9773))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0039), tensor(0.0095))  (tensor(-0.0016), tensor(0.0045))
#
# (tensor(-0.3055), tensor(0.3215))  (tensor(-2.4113), tensor(1.7080))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0201), tensor(0.0119))  (tensor(-0.0069), tensor(0.0071))
#
# (tensor(-0.6311), tensor(0.4158))  (tensor(-1.6534), tensor(1.9054))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 698 complete
#
#
# (tensor(-0.0035), tensor(0.0037))  (tensor(-0.0010), tensor(0.0036))
#
# (tensor(-0.6526), tensor(0.4782))  (tensor(-2.1665), tensor(1.2084))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0079), tensor(0.0062))  (tensor(-0.0071), tensor(0.0044))
#
# (tensor(-0.2021), tensor(0.1957))  (tensor(-0.3867), tensor(1.9786))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0052), tensor(0.0065))  (tensor(-0.0027), tensor(0.0032))
#
# (tensor(-0.3055), tensor(0.3214))  (tensor(-2.4113), tensor(1.7063))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0107), tensor(0.0106))  (tensor(-0.0052), tensor(0.0066))
#
# (tensor(-0.6279), tensor(0.4158))  (tensor(-1.6491), tensor(1.9047))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 699 complete
#
#
# Epoch 0 complete!
#
#
# Epoch 0 minibatch 0 achieved accuracy 0.234375
# Epoch 0 minibatch 1 achieved accuracy 0.2265625
# Epoch 0 minibatch 2 achieved accuracy 0.2552083333333333
# Epoch 0 minibatch 3 achieved accuracy 0.26171875
# Epoch 0 minibatch 4 achieved accuracy 0.24375
# Epoch 0 minibatch 5 achieved accuracy 0.2526041666666667
# Epoch 0 minibatch 6 achieved accuracy 0.24330357142857142
# Epoch 0 minibatch 7 achieved accuracy 0.2421875
# Epoch 0 minibatch 8 achieved accuracy 0.2482638888888889
# Epoch 0 minibatch 9 achieved accuracy 0.24375
# (tensor(-0.0040), tensor(0.0025))  (tensor(-0.0028), tensor(0.0019))
#
# (tensor(-0.6540), tensor(0.4786))  (tensor(-2.1665), tensor(1.2065))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0087), tensor(0.0038))  (tensor(-0.0067), tensor(0.0044))
#
# (tensor(-0.2021), tensor(0.1958))  (tensor(-0.3842), tensor(1.9808))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0032), tensor(0.0079))  (tensor(-0.0018), tensor(0.0046))
#
# (tensor(-0.3055), tensor(0.3214))  (tensor(-2.4113), tensor(1.7052))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0109), tensor(0.0082))  (tensor(-0.0055), tensor(0.0050))
#
# (tensor(-0.6255), tensor(0.4158))  (tensor(-1.6436), tensor(1.9049))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 521 complete
#
#
# (tensor(-0.0052), tensor(0.0053))  (tensor(-0.0034), tensor(0.0033))
#
# (tensor(-0.6547), tensor(0.4777))  (tensor(-2.1665), tensor(1.2048))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0113), tensor(0.0033))  (tensor(-0.0083), tensor(0.0065))
#
# (tensor(-0.2021), tensor(0.1956))  (tensor(-0.3840), tensor(1.9837))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0037), tensor(0.0053))  (tensor(-0.0021), tensor(0.0028))
#
# (tensor(-0.3055), tensor(0.3213))  (tensor(-2.4113), tensor(1.7054))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0125), tensor(0.0083))  (tensor(-0.0064), tensor(0.0049))
#
# (tensor(-0.6254), tensor(0.4158))  (tensor(-1.6396), tensor(1.9009))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 522 complete
#
#
# (tensor(-0.0034), tensor(0.0068))  (tensor(-0.0019), tensor(0.0014))
#
# (tensor(-0.6545), tensor(0.4770))  (tensor(-2.1665), tensor(1.2054))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0053), tensor(0.0055))  (tensor(-0.0037), tensor(0.0042))
#
# (tensor(-0.2021), tensor(0.1954))  (tensor(-0.3843), tensor(1.9854))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0054), tensor(0.0050))  (tensor(-0.0019), tensor(0.0021))
#
# (tensor(-0.3055), tensor(0.3213))  (tensor(-2.4113), tensor(1.7046))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0109), tensor(0.0062))  (tensor(-0.0043), tensor(0.0029))
#
# (tensor(-0.6254), tensor(0.4157))  (tensor(-1.6353), tensor(1.9020))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 523 complete
#
#
# (tensor(-0.0050), tensor(0.0051))  (tensor(-0.0034), tensor(0.0022))
#
# (tensor(-0.6547), tensor(0.4769))  (tensor(-2.1665), tensor(1.2042))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0062), tensor(0.0038))  (tensor(-0.0045), tensor(0.0012))
#
# (tensor(-0.2021), tensor(0.1953))  (tensor(-0.3828), tensor(1.9873))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0045), tensor(0.0036))  (tensor(-0.0019), tensor(0.0015))
#
# (tensor(-0.3055), tensor(0.3214))  (tensor(-2.4113), tensor(1.7043))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0087), tensor(0.0075))  (tensor(-0.0038), tensor(0.0033))
#
# (tensor(-0.6255), tensor(0.4157))  (tensor(-1.6334), tensor(1.9001))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 524 complete
#
#
# (tensor(-0.0038), tensor(0.0048))  (tensor(-0.0028), tensor(0.0007))
#
# (tensor(-0.6542), tensor(0.4768))  (tensor(-2.1665), tensor(1.2070))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0076), tensor(0.0045))  (tensor(-0.0027), tensor(0.0006))
#
# (tensor(-0.2021), tensor(0.1948))  (tensor(-0.3824), tensor(1.9894))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0038), tensor(0.0036))  (tensor(-0.0012), tensor(0.0011))
#
# (tensor(-0.3055), tensor(0.3214))  (tensor(-2.4113), tensor(1.7050))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0077), tensor(0.0072))  (tensor(-0.0025), tensor(0.0032))
#
# (tensor(-0.6255), tensor(0.4156))  (tensor(-1.6316), tensor(1.9001))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 525 complete
#
#
# (tensor(-0.0080), tensor(0.0033))  (tensor(-0.0030), tensor(0.0030))
#
# (tensor(-0.6550), tensor(0.4767))  (tensor(-2.1665), tensor(1.2056))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0134), tensor(0.0074))  (tensor(-0.0081), tensor(0.0017))
#
# (tensor(-0.2021), tensor(0.1945))  (tensor(-0.3830), tensor(1.9917))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0076), tensor(0.0073))  (tensor(-0.0019), tensor(0.0017))
#
# (tensor(-0.3055), tensor(0.3215))  (tensor(-2.4113), tensor(1.7046))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0115), tensor(0.0105))  (tensor(-0.0035), tensor(0.0052))
#
# (tensor(-0.6253), tensor(0.4155))  (tensor(-1.6308), tensor(1.8971))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 526 complete
#
#
# Epoch 1 complete!
#
#
# Epoch 1 minibatch 0 achieved accuracy 0.328125
# Epoch 1 minibatch 1 achieved accuracy 0.265625
# Epoch 1 minibatch 2 achieved accuracy 0.2708333333333333
# Epoch 1 minibatch 3 achieved accuracy 0.26953125
# Epoch 1 minibatch 4 achieved accuracy 0.278125
# Epoch 1 minibatch 5 achieved accuracy 0.296875
# Epoch 1 minibatch 6 achieved accuracy 0.30580357142857145
# Epoch 1 minibatch 7 achieved accuracy 0.30078125
# Epoch 1 minibatch 8 achieved accuracy 0.3020833333333333
# Epoch 1 minibatch 9 achieved accuracy 0.29375
# (tensor(-0.0058), tensor(0.0076))  (tensor(-0.0044), tensor(0.0007))
#
# (tensor(-0.6542), tensor(0.4770))  (tensor(-2.1665), tensor(1.2093))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0101), tensor(0.0099))  (tensor(-0.0033), tensor(0.0033))
#
# (tensor(-0.2021), tensor(0.1943))  (tensor(-0.3819), tensor(1.9932))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0059), tensor(0.0047))  (tensor(-0.0025), tensor(0.0019))
#
# (tensor(-0.3055), tensor(0.3215))  (tensor(-2.4113), tensor(1.7036))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0120), tensor(0.0084))  (tensor(-0.0040), tensor(0.0033))
#
# (tensor(-0.6253), tensor(0.4155))  (tensor(-1.6276), tensor(1.8978))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 490 complete
#
#
# (tensor(-0.0037), tensor(0.0056))  (tensor(-0.0022), tensor(0.0025))
#
# (tensor(-0.6543), tensor(0.4775))  (tensor(-2.1665), tensor(1.2094))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0048), tensor(0.0064))  (tensor(-0.0028), tensor(0.0019))
#
# (tensor(-0.2021), tensor(0.1945))  (tensor(-0.3817), tensor(1.9949))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0054), tensor(0.0030))  (tensor(-0.0012), tensor(0.0007))
#
# (tensor(-0.3055), tensor(0.3216))  (tensor(-2.4113), tensor(1.7036))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0076), tensor(0.0078))  (tensor(-0.0016), tensor(0.0032))
#
# (tensor(-0.6253), tensor(0.4154))  (tensor(-1.6264), tensor(1.8989))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 491 complete
#
#
# (tensor(-0.0042), tensor(0.0017))  (tensor(-0.0015), tensor(0.0005))
#
# (tensor(-0.6544), tensor(0.4778))  (tensor(-2.1665), tensor(1.2094))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0034), tensor(0.0036))  (tensor(-0.0023), tensor(0.0058))
#
# (tensor(-0.2021), tensor(0.1942))  (tensor(-0.3823), tensor(1.9967))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0043), tensor(0.0032))  (tensor(-0.0008), tensor(0.0011))
#
# (tensor(-0.3055), tensor(0.3215))  (tensor(-2.4113), tensor(1.7025))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0080), tensor(0.0077))  (tensor(-0.0026), tensor(0.0025))
#
# (tensor(-0.6253), tensor(0.4153))  (tensor(-1.6238), tensor(1.8994))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 492 complete
#
#
# (tensor(-0.0074), tensor(0.0020))  (tensor(-0.0040), tensor(0.0006))
#
# (tensor(-0.6552), tensor(0.4782))  (tensor(-2.1665), tensor(1.2088))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0050), tensor(0.0019))  (tensor(-0.0027), tensor(0.0009))
#
# (tensor(-0.2021), tensor(0.1934))  (tensor(-0.3815), tensor(1.9979))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0038), tensor(0.0022))  (tensor(-0.0009), tensor(0.0006))
#
# (tensor(-0.3055), tensor(0.3216))  (tensor(-2.4113), tensor(1.7030))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0065), tensor(0.0047))  (tensor(-0.0012), tensor(0.0021))
#
# (tensor(-0.6253), tensor(0.4153))  (tensor(-1.6231), tensor(1.9003))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 493 complete
#
#
# (tensor(-0.0055), tensor(0.0017))  (tensor(-0.0027), tensor(0.0001))
#
# (tensor(-0.6557), tensor(0.4785))  (tensor(-2.1665), tensor(1.2089))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0056), tensor(0.0015))  (tensor(-0.0017), tensor(0.0002))
#
# (tensor(-0.2021), tensor(0.1932))  (tensor(-0.3812), tensor(1.9982))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0051), tensor(0.0030))  (tensor(-0.0012), tensor(0.0008))
#
# (tensor(-0.3055), tensor(0.3216))  (tensor(-2.4113), tensor(1.7026))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0074), tensor(0.0047))  (tensor(-0.0015), tensor(0.0017))
#
# (tensor(-0.6253), tensor(0.4153))  (tensor(-1.6247), tensor(1.8994))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 494 complete
#
#
# (tensor(-0.0062), tensor(0.0021))  (tensor(-0.0043), tensor(0.0018))
#
# (tensor(-0.6568), tensor(0.4783))  (tensor(-2.1665), tensor(1.2071))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0074), tensor(0.0033))  (tensor(-0.0025), tensor(0.0017))
#
# (tensor(-0.2021), tensor(0.1928))  (tensor(-0.3810), tensor(2.0003))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0041), tensor(0.0064))  (tensor(-0.0013), tensor(0.0015))
#
# (tensor(-0.3055), tensor(0.3217))  (tensor(-2.4113), tensor(1.7031))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0098), tensor(0.0099))  (tensor(-0.0028), tensor(0.0035))
#
# (tensor(-0.6253), tensor(0.4152))  (tensor(-1.6219), tensor(1.8991))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 495 complete
#
#
# Epoch 2 complete!
#
#
# Epoch 2 minibatch 0 achieved accuracy 0.609375
# Epoch 2 minibatch 1 achieved accuracy 0.515625
# Epoch 2 minibatch 2 achieved accuracy 0.4895833333333333
# Epoch 2 minibatch 3 achieved accuracy 0.484375
# Epoch 2 minibatch 4 achieved accuracy 0.48125
# Epoch 2 minibatch 5 achieved accuracy 0.4817708333333333
# Epoch 2 minibatch 6 achieved accuracy 0.484375
# Epoch 2 minibatch 7 achieved accuracy 0.47265625
# Epoch 2 minibatch 8 achieved accuracy 0.4739583333333333
# Epoch 2 minibatch 9 achieved accuracy 0.4765625
# (tensor(-0.0049), tensor(0.0025))  (tensor(-0.0018), tensor(0.0008))
#
# (tensor(-0.6569), tensor(0.4782))  (tensor(-2.1665), tensor(1.2089))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0031), tensor(0.0070))  (tensor(-0.0009), tensor(0.0015))
#
# (tensor(-0.2021), tensor(0.1925))  (tensor(-0.3810), tensor(2.0009))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0069), tensor(0.0048))  (tensor(-0.0013), tensor(0.0006))
#
# (tensor(-0.3055), tensor(0.3217))  (tensor(-2.4113), tensor(1.7030))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0097), tensor(0.0040))  (tensor(-0.0015), tensor(0.0012))
#
# (tensor(-0.6253), tensor(0.4152))  (tensor(-1.6224), tensor(1.9006))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 606 complete
#
#
# (tensor(-0.0083), tensor(0.0015))  (tensor(-0.0060), tensor(0.0007))
#
# (tensor(-0.6574), tensor(0.4782))  (tensor(-2.1665), tensor(1.2095))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0083), tensor(0.0032))  (tensor(-0.0026), tensor(0.0006))
#
# (tensor(-0.2021), tensor(0.1919))  (tensor(-0.3801), tensor(2.0020))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0045), tensor(0.0029))  (tensor(-0.0011), tensor(0.0008))
#
# (tensor(-0.3055), tensor(0.3217))  (tensor(-2.4113), tensor(1.7030))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0149), tensor(0.0051))  (tensor(-0.0031), tensor(0.0015))
#
# (tensor(-0.6253), tensor(0.4151))  (tensor(-1.6215), tensor(1.8991))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 607 complete
#
#
# (tensor(-0.0036), tensor(0.0156))  (tensor(-0.0027), tensor(0.0074))
#
# (tensor(-0.6575), tensor(0.4778))  (tensor(-2.1665), tensor(1.2107))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0057), tensor(0.0111))  (tensor(-0.0021), tensor(0.0039))
#
# (tensor(-0.2021), tensor(0.1921))  (tensor(-0.3816), tensor(2.0028))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0073), tensor(0.0110))  (tensor(-0.0024), tensor(0.0019))
#
# (tensor(-0.3055), tensor(0.3218))  (tensor(-2.4113), tensor(1.7039))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0202), tensor(0.0162))  (tensor(-0.0035), tensor(0.0041))
#
# (tensor(-0.6253), tensor(0.4151))  (tensor(-1.6247), tensor(1.9026))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 608 complete
#
#
# (tensor(-0.0064), tensor(0.0022))  (tensor(-0.0043), tensor(0.0009))
#
# (tensor(-0.6579), tensor(0.4783))  (tensor(-2.1665), tensor(1.2122))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0086), tensor(0.0045))  (tensor(-0.0030), tensor(0.0019))
#
# (tensor(-0.2021), tensor(0.1907))  (tensor(-0.3801), tensor(2.0045))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0093), tensor(0.0070))  (tensor(-0.0021), tensor(0.0012))
#
# (tensor(-0.3055), tensor(0.3218))  (tensor(-2.4113), tensor(1.7032))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0136), tensor(0.0129))  (tensor(-0.0040), tensor(0.0044))
#
# (tensor(-0.6253), tensor(0.4151))  (tensor(-1.6208), tensor(1.8996))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 609 complete
#
#
# (tensor(-0.0049), tensor(0.0031))  (tensor(-0.0034), tensor(0.0024))
#
# (tensor(-0.6583), tensor(0.4788))  (tensor(-2.1665), tensor(1.2098))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0053), tensor(0.0053))  (tensor(-0.0018), tensor(0.0013))
#
# (tensor(-0.2021), tensor(0.1910))  (tensor(-0.3813), tensor(2.0063))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0054), tensor(0.0051))  (tensor(-0.0014), tensor(0.0008))
#
# (tensor(-0.3055), tensor(0.3219))  (tensor(-2.4113), tensor(1.7033))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0079), tensor(0.0111))  (tensor(-0.0019), tensor(0.0032))
#
# (tensor(-0.6253), tensor(0.4150))  (tensor(-1.6206), tensor(1.8996))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 610 complete
#
#
# (tensor(-0.0056), tensor(0.0006))  (tensor(-0.0037), tensor(0.0002))
#
# (tensor(-0.6583), tensor(0.4789))  (tensor(-2.1665), tensor(1.2123))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0041), tensor(0.0034))  (tensor(-0.0014), tensor(0.0018))
#
# (tensor(-0.2021), tensor(0.1898))  (tensor(-0.3802), tensor(2.0063))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0057), tensor(0.0041))  (tensor(-0.0012), tensor(0.0009))
#
# (tensor(-0.3055), tensor(0.3219))  (tensor(-2.4113), tensor(1.7027))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0072), tensor(0.0077))  (tensor(-0.0016), tensor(0.0021))
#
# (tensor(-0.6253), tensor(0.4148))  (tensor(-1.6190), tensor(1.8993))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 611 complete
#
#
# Epoch 3 complete!
#
#
# Epoch 3 minibatch 0 achieved accuracy 0.640625
# Epoch 3 minibatch 1 achieved accuracy 0.6484375
# Epoch 3 minibatch 2 achieved accuracy 0.65625
# Epoch 3 minibatch 3 achieved accuracy 0.6484375
# Epoch 3 minibatch 4 achieved accuracy 0.6625
# Epoch 3 minibatch 5 achieved accuracy 0.6380208333333334
# Epoch 3 minibatch 6 achieved accuracy 0.6495535714285714
# Epoch 3 minibatch 7 achieved accuracy 0.65234375
# Epoch 3 minibatch 8 achieved accuracy 0.6354166666666666
# Epoch 3 minibatch 9 achieved accuracy 0.628125
# (tensor(-0.0040), tensor(0.0017))  (tensor(-0.0028), tensor(0.0004))
#
# (tensor(-0.6581), tensor(0.4790))  (tensor(-2.1665), tensor(1.2134))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0029), tensor(0.0038))  (tensor(-0.0013), tensor(0.0010))
#
# (tensor(-0.2021), tensor(0.1896))  (tensor(-0.3804), tensor(2.0075))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0048), tensor(0.0072))  (tensor(-0.0008), tensor(0.0007))
#
# (tensor(-0.3055), tensor(0.3220))  (tensor(-2.4113), tensor(1.7031))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0078), tensor(0.0049))  (tensor(-0.0016), tensor(0.0017))
#
# (tensor(-0.6253), tensor(0.4148))  (tensor(-1.6190), tensor(1.8995))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 115 complete
#
#
# (tensor(-0.0049), tensor(0.0013))  (tensor(-0.0022), tensor(0.0005))
#
# (tensor(-0.6575), tensor(0.4794))  (tensor(-2.1665), tensor(1.2157))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0045), tensor(0.0056))  (tensor(-0.0029), tensor(0.0015))
#
# (tensor(-0.2021), tensor(0.1891))  (tensor(-0.3792), tensor(2.0081))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0069), tensor(0.0067))  (tensor(-0.0013), tensor(0.0010))
#
# (tensor(-0.3055), tensor(0.3220))  (tensor(-2.4113), tensor(1.7030))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0084), tensor(0.0082))  (tensor(-0.0022), tensor(0.0029))
#
# (tensor(-0.6253), tensor(0.4147))  (tensor(-1.6184), tensor(1.8987))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 116 complete
#
#
# (tensor(-0.0036), tensor(0.0057))  (tensor(-0.0034), tensor(0.0008))
#
# (tensor(-0.6572), tensor(0.4795))  (tensor(-2.1665), tensor(1.2179))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0075), tensor(0.0044))  (tensor(-0.0008), tensor(0.0015))
#
# (tensor(-0.2021), tensor(0.1891))  (tensor(-0.3799), tensor(2.0076))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0054), tensor(0.0069))  (tensor(-0.0014), tensor(0.0012))
#
# (tensor(-0.3055), tensor(0.3221))  (tensor(-2.4113), tensor(1.7030))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0120), tensor(0.0075))  (tensor(-0.0026), tensor(0.0017))
#
# (tensor(-0.6253), tensor(0.4147))  (tensor(-1.6196), tensor(1.9003))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 117 complete
#
#
# (tensor(-0.0060), tensor(0.0013))  (tensor(-0.0038), tensor(0.0005))
#
# (tensor(-0.6573), tensor(0.4803))  (tensor(-2.1665), tensor(1.2179))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0080), tensor(0.0027))  (tensor(-0.0021), tensor(0.0018))
#
# (tensor(-0.2021), tensor(0.1885))  (tensor(-0.3793), tensor(2.0078))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0059), tensor(0.0113))  (tensor(-0.0013), tensor(0.0019))
#
# (tensor(-0.3055), tensor(0.3221))  (tensor(-2.4113), tensor(1.7041))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0118), tensor(0.0153))  (tensor(-0.0018), tensor(0.0029))
#
# (tensor(-0.6253), tensor(0.4147))  (tensor(-1.6181), tensor(1.8974))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 118 complete
#
#
# (tensor(-0.0022), tensor(0.0045))  (tensor(-0.0012), tensor(0.0030))
#
# (tensor(-0.6575), tensor(0.4797))  (tensor(-2.1665), tensor(1.2156))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0088), tensor(0.0102))  (tensor(-0.0032), tensor(0.0030))
#
# (tensor(-0.2021), tensor(0.1886))  (tensor(-0.3810), tensor(2.0078))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0137), tensor(0.0106))  (tensor(-0.0028), tensor(0.0018))
#
# (tensor(-0.3055), tensor(0.3221))  (tensor(-2.4113), tensor(1.7031))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0207), tensor(0.0129))  (tensor(-0.0054), tensor(0.0032))
#
# (tensor(-0.6253), tensor(0.4146))  (tensor(-1.6213), tensor(1.8977))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 119 complete
#
#
# (tensor(-0.0063), tensor(0.0094))  (tensor(-0.0036), tensor(0.0032))
#
# (tensor(-0.6575), tensor(0.4809))  (tensor(-2.1665), tensor(1.2176))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0065), tensor(0.0201))  (tensor(-0.0018), tensor(0.0055))
#
# (tensor(-0.2021), tensor(0.1882))  (tensor(-0.3793), tensor(2.0074))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0092), tensor(0.0182))  (tensor(-0.0016), tensor(0.0025))
#
# (tensor(-0.3055), tensor(0.3221))  (tensor(-2.4113), tensor(1.7036))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# (tensor(-0.0135), tensor(0.0170))  (tensor(-0.0036), tensor(0.0051))
#
# (tensor(-0.6253), tensor(0.4146))  (tensor(-1.6177), tensor(1.8979))
#
# (tensor(0.), tensor(0.))  (tensor(0.), tensor(0.))
#
#
# Minibatch 120 complete
#
#
# Epoch 4 complete!
#
#
# Epoch 4 minibatch 0 achieved accuracy 0.546875
# Epoch 4 minibatch 1 achieved accuracy 0.5546875
# Epoch 4 minibatch 2 achieved accuracy 0.5625
# Epoch 4 minibatch 3 achieved accuracy 0.5625
# Epoch 4 minibatch 4 achieved accuracy 0.571875
# Epoch 4 minibatch 5 achieved accuracy 0.5807291666666666
# Epoch 4 minibatch 6 achieved accuracy 0.5736607142857143
# Epoch 4 minibatch 7 achieved accuracy 0.576171875
# Epoch 4 minibatch 8 achieved accuracy 0.5798611111111112
# Epoch 4 minibatch 9 achieved accuracy 0.571875
