# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,"/content/drive/My Drive/Colab Notebooks/NeuralNetwork")

# %%
import math
import os
from tempfile import TemporaryDirectory
from typing import Tuple
import sys

import torch
from torch import nn, Tensor
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer
from torch.utils.data import dataset

import numpy as np
import random
import copy
import torch.optim as optim
import pickle
import os
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
sys.path.append("/Volumes/GoogleDrive/My Drive/Colab Notebooks/NeuralNetwork")
from library_model import layers as lay
from library_model import model_building as mb
from library_model import model_training as mt
from data import data_loading as dt
from data import text as txt

# %%
# %%bash
# pip install torchdata
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchdata
#   Downloading torchdata-0.5.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 56.6 MB/s eta 0:00:00
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.8/dist-packages (from torchdata) (1.13.1+cu116)
# Collecting portalocker>=2.0.0
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchdata) (2.25.1)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.8/dist-packages (from torchdata) (1.26.14)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->torchdata) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchdata) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchdata) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchdata) (4.0.0)
# Installing collected packages: portalocker, torchdata
# Successfully installed portalocker-2.7.0 torchdata-0.5.1

# %%
# %%bash
# pip install torchtext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchtext in /usr/local/lib/python3.8/dist-packages (0.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchtext) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext) (2.25.1)
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.8/dist-packages (from torchtext) (1.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->torchtext) (4.5.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext) (2022.12.7)

# %% [markdown]
# #Download Data

# %%
from torchtext.datasets import WikiText2
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

train_iter = WikiText2(split='train')

# %%
dataset_size = sum((1 for _ in train_iter))
dataset_size
# Out:
# 36718

# %% [markdown]
# # Construct networks of different sizes

# %% [markdown]
# Fixed depth, varying width

# %%
states_wide = [lay.Network_state() for _ in range(3)]
for k, state in enumerate(states_wide):
    p= state.parameters
    tr= state.training

    p.d_model=200+100*k
    p.d_hid=200+100*k
    p.nheads=2 + k
    p.d_key = p.d_model //p.nheads
    p.nlayers=2
    p.network = "encoder"


    tr.batch_size=20
    tr.data_split = 0.8 #fraction of dataset that will be used for training vs validation
    tr.lr = 1.
    tr.seq_length=35
    tr.optimizer = "sgd"

# %% [markdown]
# fixed width, varying depth

# %%
states_deep = [lay.Network_state() for _ in range(3)]
for k, state in enumerate(states_deep):
    p= state.parameters
    tr= state.training

    p.d_model=200
    p.d_hid=200
    p.nheads=2 
    p.d_key = p.d_model //p.nheads
    p.nlayers=2+k
    p.network = "encoder"


    tr.batch_size=20
    tr.data_split = 0.8 #fraction of dataset that will be used for training vs validation
    tr.lr = 1.
    tr.seq_length=35
    tr.optimizer = "sgd"

# %% [markdown]
# fixed aspect ratio

# %%
states_scaled = [lay.Network_state() for _ in range(3)]
for k, state in enumerate(states_scaled):
    p= state.parameters
    tr= state.training

    p.d_model=200+100*k
    p.d_hid=200+100*k
    p.nheads=2 + k
    p.d_key = p.d_model //p.nheads
    p.nlayers=2+k
    p.network = "encoder"


    tr.batch_size=20
    tr.data_split = 0.8 #fraction of dataset that will be used for training vs validation
    tr.lr = 1.
    tr.seq_length=35
    tr.optimizer = "sgd"

# %%
param_count = list(map(lay.param_count, [*states_wide, *states_deep[1:], *states_scaled[1:]]))
param_count
# Out:
# [480000, 1080000, 1920000, 720000, 960000, 1620000, 3840000]

# %% [markdown]
# # Get Dataloaders

# %%
def learning_rate_cosine(factor, length, finalLR):
    return lambda step : (factor/2) *(torch.cos(torch.tensor(step/length*3.14))+1) +finalLR

# %%
dataset = dt.Data()
num_epochs = 3

dataset.tokenizer, dataset.train_dataloader, dataset.test_dataloader = dt.process_data(train_iter, txt.library_text_coders, states_deep[0], network= "encoder")
for s in [*states_deep, *states_wide, *states_scaled]:
  s.parameters.ntokens = s.parameters.ntokens_out = len(dataset.tokenizer.vocab)
  s.training.schedule = learning_rate_cosine(factor=5., length = 2300*num_epochs, finalLR=0.5)

# %% [markdown]
# # Experiment 1: Varying width, depth or scale, fixed dataset, trained to convergence

# %%
criterion = nn.CrossEntropyLoss()
model_train_curves = []
model_test_curves =[]
min_losses = []
k=0
for state in [*states_wide, *states_deep[1:], *states_scaled[1:]]:
    #build model
    print(f"***Model {k+1}*** \n Parameters {param_count[k]:.1E}\n\n")
    k+=1
    parts = mb.get_transformer_parts(state)
    model = lay.EncoderModel(parts.encoder, parts.linear).to(state.device)
    #train model
    opt, scheduler = mb.get_optimizer(state, model)
    trainer = mt.Model_training(model, opt, criterion, scheduler)
    trainer(epochs=3, data= dataset)
    #record training data
    min_losses.append(trainer.min_loss)
    model_train_curves.append(trainer.train_loss)
    model_test_curves.append(trainer.test_loss)
# Out:
# ***Model 1***
#  Parameters 4.8E+05
#
#
# Batch 200 | lr = 5.490 | time =  0.08 | train_loss  9.13
# Batch 400 | lr = 5.459 | time =  0.11 | train_loss  8.01
# Batch 600 | lr = 5.408 | time =  0.09 | train_loss  7.51
# Batch 800 | lr = 5.337 | time =  0.08 | train_loss  7.34
# Batch 1000 | lr = 5.246 | time =  0.10 | train_loss  7.21
# Batch 1200 | lr = 5.137 | time =  0.08 | train_loss  7.09
# Batch 1400 | lr = 5.010 | time =  0.08 | train_loss  7.02
# Batch 1600 | lr = 4.867 | time =  0.09 | train_loss  6.90
# Batch 1800 | lr = 4.708 | time =  0.09 | train_loss  6.84
# Batch 2000 | lr = 4.535 | time =  0.08 | train_loss  6.78
# Batch 2200 | lr = 4.349 | time =  0.08 | train_loss  6.69
# Epoch: 0 | time: 60.68 | test_loss =  6.61
#
# Batch 200 | lr = 4.007 | time =  0.08 | train_loss  6.57
# Batch 400 | lr = 3.795 | time =  0.08 | train_loss  6.49
# Batch 600 | lr = 3.576 | time =  0.08 | train_loss  6.47
# Batch 800 | lr = 3.352 | time =  0.08 | train_loss  6.41
# Batch 1000 | lr = 3.126 | time =  0.08 | train_loss  6.36
# Batch 1200 | lr = 2.898 | time =  0.08 | train_loss  6.32
# Batch 1400 | lr = 2.672 | time =  0.08 | train_loss  6.27
# Batch 1600 | lr = 2.448 | time =  0.09 | train_loss  6.24
# Batch 1800 | lr = 2.229 | time =  0.08 | train_loss  6.16
# Batch 2000 | lr = 2.016 | time =  0.11 | train_loss  6.19
# Batch 2200 | lr = 1.811 | time =  0.07 | train_loss  6.14
# Epoch: 1 | time: 58.85 | test_loss =  6.21
#
# Batch 200 | lr = 1.484 | time =  0.08 | train_loss  6.06
# Batch 400 | lr = 1.310 | time =  0.08 | train_loss  6.06
# Batch 600 | lr = 1.150 | time =  0.08 | train_loss  6.03
# Batch 800 | lr = 1.004 | time =  0.09 | train_loss  6.01
# Batch 1000 | lr = 0.876 | time =  0.08 | train_loss  6.03
# Batch 1200 | lr = 0.765 | time =  0.08 | train_loss  6.03
# Batch 1400 | lr = 0.672 | time =  0.08 | train_loss  6.01
# Batch 1600 | lr = 0.599 | time =  0.07 | train_loss  6.02
# Batch 1800 | lr = 0.546 | time =  0.09 | train_loss  6.00
# Batch 2000 | lr = 0.513 | time =  0.08 | train_loss  6.01
# Batch 2200 | lr = 0.500 | time =  0.09 | train_loss  5.98
# Epoch: 2 | time: 58.92 | test_loss =  6.10
# ***Model 2***
#  Parameters 1.1E+06
#
#
# Batch 200 | lr = 5.490 | time =  0.11 | train_loss  9.22
# Batch 400 | lr = 5.459 | time =  0.11 | train_loss  7.96
# Batch 600 | lr = 5.408 | time =  0.11 | train_loss  7.53
# Batch 800 | lr = 5.337 | time =  0.11 | train_loss  7.35
# Batch 1000 | lr = 5.246 | time =  0.11 | train_loss  7.19
# Batch 1200 | lr = 5.137 | time =  0.11 | train_loss  7.11
# Batch 1400 | lr = 5.010 | time =  0.11 | train_loss  7.02
# Batch 1600 | lr = 4.867 | time =  0.10 | train_loss  6.91
# Batch 1800 | lr = 4.708 | time =  0.11 | train_loss  6.81
# Batch 2000 | lr = 4.535 | time =  0.12 | train_loss  6.74
# Batch 2200 | lr = 4.349 | time =  0.11 | train_loss  6.74
# Epoch: 0 | time: 74.41 | test_loss =  6.83
#
# Batch 200 | lr = 4.007 | time =  0.11 | train_loss  6.56
# Batch 400 | lr = 3.795 | time =  0.11 | train_loss  6.50
# Batch 600 | lr = 3.576 | time =  0.11 | train_loss  6.45
# Batch 800 | lr = 3.352 | time =  0.11 | train_loss  6.40
# Batch 1000 | lr = 3.126 | time =  0.10 | train_loss  6.35
# Batch 1200 | lr = 2.898 | time =  0.10 | train_loss  6.34
# Batch 1400 | lr = 2.672 | time =  0.11 | train_loss  6.33
# Batch 1600 | lr = 2.448 | time =  0.11 | train_loss  6.25
# Batch 1800 | lr = 2.229 | time =  0.11 | train_loss  6.22
# Batch 2000 | lr = 2.016 | time =  0.12 | train_loss  6.20
# Batch 2200 | lr = 1.811 | time =  0.11 | train_loss  6.16
# Epoch: 1 | time: 75.21 | test_loss =  6.21
#
# Batch 200 | lr = 1.484 | time =  0.11 | train_loss  6.07
# Batch 400 | lr = 1.310 | time =  0.08 | train_loss  6.07
# Batch 600 | lr = 1.150 | time =  0.11 | train_loss  6.06
# Batch 800 | lr = 1.004 | time =  0.11 | train_loss  6.05
# Batch 1000 | lr = 0.876 | time =  0.09 | train_loss  6.03
# Batch 1200 | lr = 0.765 | time =  0.09 | train_loss  6.05
# Batch 1400 | lr = 0.672 | time =  0.11 | train_loss  6.02
# Batch 1600 | lr = 0.599 | time =  0.11 | train_loss  6.01
# Batch 1800 | lr = 0.546 | time =  0.11 | train_loss  6.04
# Batch 2000 | lr = 0.513 | time =  0.11 | train_loss  5.99
# Batch 2200 | lr = 0.500 | time =  0.11 | train_loss  5.98
# Epoch: 2 | time: 75.38 | test_loss =  6.11
# ***Model 3***
#  Parameters 1.9E+06
#
#
# Batch 200 | lr = 5.490 | time =  0.14 | train_loss  9.56
# Batch 400 | lr = 5.459 | time =  0.15 | train_loss  7.98
# Batch 600 | lr = 5.408 | time =  0.14 | train_loss  7.55
# Batch 800 | lr = 5.337 | time =  0.14 | train_loss  7.21
# Batch 1000 | lr = 5.246 | time =  0.13 | train_loss  7.14
# Batch 1200 | lr = 5.137 | time =  0.13 | train_loss  7.02
# Batch 1400 | lr = 5.010 | time =  0.14 | train_loss  6.87
# Batch 1600 | lr = 4.867 | time =  0.14 | train_loss  6.82
# Batch 1800 | lr = 4.708 | time =  0.14 | train_loss  6.77
# Batch 2000 | lr = 4.535 | time =  0.14 | train_loss  6.69
# Batch 2200 | lr = 4.349 | time =  0.13 | train_loss  6.62
# Epoch: 0 | time: 90.22 | test_loss =  6.51
#
# Batch 200 | lr = 4.007 | time =  0.13 | train_loss  6.49
# Batch 400 | lr = 3.795 | time =  0.13 | train_loss  6.47
# Batch 600 | lr = 3.576 | time =  0.14 | train_loss  6.39
# Batch 800 | lr = 3.352 | time =  0.14 | train_loss  6.33
# Batch 1000 | lr = 3.126 | time =  0.14 | train_loss  6.31
# Batch 1200 | lr = 2.898 | time =  0.14 | train_loss  6.27
# Batch 1400 | lr = 2.672 | time =  0.13 | train_loss  6.21
# Batch 1600 | lr = 2.448 | time =  0.13 | train_loss  6.19
# Batch 1800 | lr = 2.229 | time =  0.14 | train_loss  6.18
# Batch 2000 | lr = 2.016 | time =  0.13 | train_loss  6.13
# Batch 2200 | lr = 1.811 | time =  0.14 | train_loss  6.09
# Epoch: 1 | time: 90.28 | test_loss =  6.17
#
# Batch 200 | lr = 1.484 | time =  0.14 | train_loss  6.03
# Batch 400 | lr = 1.310 | time =  0.14 | train_loss  6.01
# Batch 600 | lr = 1.150 | time =  0.14 | train_loss  6.02
# Batch 800 | lr = 1.004 | time =  0.14 | train_loss  6.00
# Batch 1000 | lr = 0.876 | time =  0.14 | train_loss  5.98
# Batch 1200 | lr = 0.765 | time =  0.13 | train_loss  5.96
# Batch 1400 | lr = 0.672 | time =  0.13 | train_loss  5.96
# Batch 1600 | lr = 0.599 | time =  0.13 | train_loss  5.92
# Batch 1800 | lr = 0.546 | time =  0.15 | train_loss  5.92
# Batch 2000 | lr = 0.513 | time =  0.14 | train_loss  5.93
# Batch 2200 | lr = 0.500 | time =  0.14 | train_loss  5.90
# Epoch: 2 | time: 90.70 | test_loss =  6.06
# ***Model 4***
#  Parameters 7.2E+05
#
#
# Batch 200 | lr = 5.490 | time =  0.09 | train_loss  9.11
# Batch 400 | lr = 5.459 | time =  0.11 | train_loss  8.32
# Batch 600 | lr = 5.408 | time =  0.09 | train_loss  8.00
# Batch 800 | lr = 5.337 | time =  0.10 | train_loss  8.01
# Batch 1000 | lr = 5.246 | time =  0.09 | train_loss  7.79
# Batch 1200 | lr = 5.137 | time =  0.09 | train_loss  7.76
# Batch 1400 | lr = 5.010 | time =  0.09 | train_loss  7.74
# Batch 1600 | lr = 4.867 | time =  0.09 | train_loss  7.64
# Batch 1800 | lr = 4.708 | time =  0.09 | train_loss  7.60
# Batch 2000 | lr = 4.535 | time =  0.09 | train_loss  7.53
# Batch 2200 | lr = 4.349 | time =  0.09 | train_loss  7.51
# Epoch: 0 | time: 70.92 | test_loss =  7.63
#
# Batch 200 | lr = 4.007 | time =  0.10 | train_loss  7.32
# Batch 400 | lr = 3.795 | time =  0.10 | train_loss  7.23
# Batch 600 | lr = 3.576 | time =  0.09 | train_loss  7.20
# Batch 800 | lr = 3.352 | time =  0.09 | train_loss  7.15
# Batch 1000 | lr = 3.126 | time =  0.09 | train_loss  7.09
# Batch 1200 | lr = 2.898 | time =  0.10 | train_loss  7.03
# Batch 1400 | lr = 2.672 | time =  0.11 | train_loss  6.91
# Batch 1600 | lr = 2.448 | time =  0.10 | train_loss  6.79
# Batch 1800 | lr = 2.229 | time =  0.14 | train_loss  6.71
# Batch 2000 | lr = 2.016 | time =  0.09 | train_loss  6.63
# Batch 2200 | lr = 1.811 | time =  0.11 | train_loss  6.60
# Epoch: 1 | time: 71.79 | test_loss =  6.67
#
# Batch 200 | lr = 1.484 | time =  0.09 | train_loss  6.53
# Batch 400 | lr = 1.310 | time =  0.08 | train_loss  6.49
# Batch 600 | lr = 1.150 | time =  0.09 | train_loss  6.47
# Batch 800 | lr = 1.004 | time =  0.12 | train_loss  6.45
# Batch 1000 | lr = 0.876 | time =  0.09 | train_loss  6.42
# Batch 1200 | lr = 0.765 | time =  0.11 | train_loss  6.38
# Batch 1400 | lr = 0.672 | time =  0.10 | train_loss  6.39
# Batch 1600 | lr = 0.599 | time =  0.12 | train_loss  6.34
# Batch 1800 | lr = 0.546 | time =  0.09 | train_loss  6.36
# Batch 2000 | lr = 0.513 | time =  0.12 | train_loss  6.34
# Batch 2200 | lr = 0.500 | time =  0.10 | train_loss  6.35
# Epoch: 2 | time: 70.93 | test_loss =  6.39
# ***Model 5***
#  Parameters 9.6E+05
#
#
# Batch 200 | lr = 5.490 | time =  0.11 | train_loss  9.11
# Batch 400 | lr = 5.459 | time =  0.11 | train_loss  8.39
# Batch 600 | lr = 5.408 | time =  0.10 | train_loss  8.04
# Batch 800 | lr = 5.337 | time =  0.15 | train_loss  7.86
# Batch 1000 | lr = 5.246 | time =  0.10 | train_loss  7.83
# Batch 1200 | lr = 5.137 | time =  0.14 | train_loss  7.84
# Batch 1400 | lr = 5.010 | time =  0.11 | train_loss  7.73
# Batch 1600 | lr = 4.867 | time =  0.10 | train_loss  7.64
# Batch 1800 | lr = 4.708 | time =  0.14 | train_loss  7.62
# Batch 2000 | lr = 4.535 | time =  0.14 | train_loss  7.59
# Batch 2200 | lr = 4.349 | time =  0.16 | train_loss  7.51
# Epoch: 0 | time: 83.77 | test_loss =  7.39
#
# Batch 200 | lr = 4.007 | time =  0.16 | train_loss  7.36
# Batch 400 | lr = 3.795 | time =  0.12 | train_loss  7.33
# Batch 600 | lr = 3.576 | time =  0.11 | train_loss  7.30
# Batch 800 | lr = 3.352 | time =  0.10 | train_loss  7.22
# Batch 1000 | lr = 3.126 | time =  0.12 | train_loss  7.18
# Batch 1200 | lr = 2.898 | time =  0.10 | train_loss  7.17
# Batch 1400 | lr = 2.672 | time =  0.10 | train_loss  7.12
# Batch 1600 | lr = 2.448 | time =  0.10 | train_loss  7.08
# Batch 1800 | lr = 2.229 | time =  0.12 | train_loss  7.04
# Batch 2000 | lr = 2.016 | time =  0.16 | train_loss  7.00
# Batch 2200 | lr = 1.811 | time =  0.10 | train_loss  6.97
# Epoch: 1 | time: 84.30 | test_loss =  7.01
#
# Batch 200 | lr = 1.484 | time =  0.10 | train_loss  6.95
# Batch 400 | lr = 1.310 | time =  0.14 | train_loss  6.94
# Batch 600 | lr = 1.150 | time =  0.11 | train_loss  6.92
# Batch 800 | lr = 1.004 | time =  0.11 | train_loss  6.93
# Batch 1000 | lr = 0.876 | time =  0.15 | train_loss  6.94
# Batch 1200 | lr = 0.765 | time =  0.16 | train_loss  6.91
# Batch 1400 | lr = 0.672 | time =  0.15 | train_loss  6.91
# Batch 1600 | lr = 0.599 | time =  0.10 | train_loss  6.93
# Batch 1800 | lr = 0.546 | time =  0.10 | train_loss  6.93
# Batch 2000 | lr = 0.513 | time =  0.10 | train_loss  6.91
# Batch 2200 | lr = 0.500 | time =  0.10 | train_loss  6.91
# Epoch: 2 | time: 85.57 | test_loss =  6.99
# ***Model 6***
#  Parameters 1.6E+06
#
#
# Batch 200 | lr = 5.490 | time =  0.12 | train_loss  9.32
# Batch 400 | lr = 5.459 | time =  0.12 | train_loss  8.40
# Batch 600 | lr = 5.408 | time =  0.13 | train_loss  8.10
# Batch 800 | lr = 5.337 | time =  0.14 | train_loss  7.84
# Batch 1000 | lr = 5.246 | time =  0.13 | train_loss  7.82
# Batch 1200 | lr = 5.137 | time =  0.09 | train_loss  7.67
# Batch 1400 | lr = 5.010 | time =  0.13 | train_loss  7.54
# Batch 1600 | lr = 4.867 | time =  0.13 | train_loss  7.42
# Batch 1800 | lr = 4.708 | time =  0.12 | train_loss  7.26
# Batch 2000 | lr = 4.535 | time =  0.12 | train_loss  7.16
# Batch 2200 | lr = 4.349 | time =  0.13 | train_loss  7.07
# Epoch: 0 | time: 86.06 | test_loss =  7.14
#
# Batch 200 | lr = 4.007 | time =  0.10 | train_loss  6.98
# Batch 400 | lr = 3.795 | time =  0.12 | train_loss  6.93
# Batch 600 | lr = 3.576 | time =  0.13 | train_loss  6.86
# Batch 800 | lr = 3.352 | time =  0.13 | train_loss  6.78
# Batch 1000 | lr = 3.126 | time =  0.12 | train_loss  6.72
# Batch 1200 | lr = 2.898 | time =  0.11 | train_loss  6.65
# Batch 1400 | lr = 2.672 | time =  0.12 | train_loss  6.59
# Batch 1600 | lr = 2.448 | time =  0.13 | train_loss  6.56
# Batch 1800 | lr = 2.229 | time =  0.11 | train_loss  6.51
# Batch 2000 | lr = 2.016 | time =  0.13 | train_loss  6.46
# Batch 2200 | lr = 1.811 | time =  0.11 | train_loss  6.43
# Epoch: 1 | time: 86.43 | test_loss =  6.49
#
# Batch 200 | lr = 1.484 | time =  0.12 | train_loss  6.36
# Batch 400 | lr = 1.310 | time =  0.11 | train_loss  6.34
# Batch 600 | lr = 1.150 | time =  0.12 | train_loss  6.33
# Batch 800 | lr = 1.004 | time =  0.12 | train_loss  6.31
# Batch 1000 | lr = 0.876 | time =  0.12 | train_loss  6.28
# Batch 1200 | lr = 0.765 | time =  0.12 | train_loss  6.28
# Batch 1400 | lr = 0.672 | time =  0.12 | train_loss  6.27
# Batch 1600 | lr = 0.599 | time =  0.12 | train_loss  6.24
# Batch 1800 | lr = 0.546 | time =  0.12 | train_loss  6.24
# Batch 2000 | lr = 0.513 | time =  0.12 | train_loss  6.26
# Batch 2200 | lr = 0.500 | time =  0.17 | train_loss  6.20
# Epoch: 2 | time: 85.49 | test_loss =  6.31
# ***Model 7***
#  Parameters 3.8E+06
#
#
# Batch 200 | lr = 5.490 | time =  0.17 | train_loss  9.84
# Batch 400 | lr = 5.459 | time =  0.16 | train_loss  8.44
# Batch 600 | lr = 5.408 | time =  0.17 | train_loss  8.11
# Batch 800 | lr = 5.337 | time =  0.18 | train_loss  8.00
# Batch 1000 | lr = 5.246 | time =  0.17 | train_loss  7.86
# Batch 1200 | lr = 5.137 | time =  0.16 | train_loss  7.79
# Batch 1400 | lr = 5.010 | time =  0.17 | train_loss  7.71
# Batch 1600 | lr = 4.867 | time =  0.16 | train_loss  7.69
# Batch 1800 | lr = 4.708 | time =  0.17 | train_loss  7.61
# Batch 2000 | lr = 4.535 | time =  0.20 | train_loss  7.55
# Batch 2200 | lr = 4.349 | time =  0.20 | train_loss  7.50
# Epoch: 0 | time: 114.32 | test_loss =  7.41
#
# Batch 200 | lr = 4.007 | time =  0.17 | train_loss  7.38
# Batch 400 | lr = 3.795 | time =  0.17 | train_loss  7.30
# Batch 600 | lr = 3.576 | time =  0.16 | train_loss  7.30
# Batch 800 | lr = 3.352 | time =  0.16 | train_loss  7.21
# Batch 1000 | lr = 3.126 | time =  0.16 | train_loss  7.16
# Batch 1200 | lr = 2.898 | time =  0.18 | train_loss  7.15
# Batch 1400 | lr = 2.672 | time =  0.15 | train_loss  7.09
# Batch 1600 | lr = 2.448 | time =  0.16 | train_loss  7.09
# Batch 1800 | lr = 2.229 | time =  0.17 | train_loss  7.03
# Batch 2000 | lr = 2.016 | time =  0.17 | train_loss  7.01
# Batch 2200 | lr = 1.811 | time =  0.16 | train_loss  6.99
# Epoch: 1 | time: 114.14 | test_loss =  7.01
#
# Batch 200 | lr = 1.484 | time =  0.17 | train_loss  6.95
# Batch 400 | lr = 1.310 | time =  0.16 | train_loss  6.94
# Batch 600 | lr = 1.150 | time =  0.17 | train_loss  6.94
# Batch 800 | lr = 1.004 | time =  0.16 | train_loss  6.93
# Batch 1000 | lr = 0.876 | time =  0.16 | train_loss  6.91
# Batch 1200 | lr = 0.765 | time =  0.15 | train_loss  6.93
# Batch 1400 | lr = 0.672 | time =  0.19 | train_loss  6.93
# Batch 1600 | lr = 0.599 | time =  0.17 | train_loss  6.90
# Batch 1800 | lr = 0.546 | time =  0.17 | train_loss  6.91
# Batch 2000 | lr = 0.513 | time =  0.14 | train_loss  6.92
# Batch 2200 | lr = 0.500 | time =  0.17 | train_loss  6.91
# Epoch: 2 | time: 114.31 | test_loss =  6.99

# %% [markdown]
# # Results

# %% [markdown]
# We observe a nice convergence for all models and a monotonic increase of performance as a function of network width at fixed depth = 2 layers.
#
# The performance increase, however, is small so it leads me to believe we are in the data saturated regime (we already close the optimal model size for the amount of data and the latter is now bottlenecking performance)
#
# I also observe an increase in the initial loss as the function of the size, leading me to believe there exists a better initialization of the network

# %%
plt.plot(model_train_curves[0], "r", label="d_model = 200")
plt.plot(model_train_curves[1], "b", label="d_model = 300")
plt.plot(model_train_curves[2], "g", label="d_model = 400") 
plt.legend(loc = "upper right")
plt.ylabel("training loss")
plt.xlabel("batch/200")
plt.title("Fixed depth = 2 layers")
# Out:
# Text(0.5, 1.0, 'Fixed depth = 2 layers')

# %%
plt.plot(model_test_curves[0], "r",  label="d_model = 200") 
plt.plot(model_test_curves[1], "b",  label="d_model = 300")
plt.plot(model_test_curves[2], "g", label="d_model = 400")
plt.legend(loc = "upper right")
plt.ylabel("test loss")
plt.xlabel("batch/400")
plt.title("Fixed depth = 2 layers")
# Out:
# Text(0.5, 1.0, 'Fixed depth = 2 layers')

# %% [markdown]
# On the other hand, we observe a rather dramatic decrease of performance as a function of depth at fixed width. I tentatively attribute this to bad information propagation through the network at fixed width as we increase the depth. (I did the same experiment using Pytorch's built in Transformer model to rule out code bugs and it exhibited a similar behavior)

# %%
plt.plot(model_train_curves[0], "r", label="layers = 2")
plt.plot(model_train_curves[3], "b", label="layers = 3")
plt.plot(model_train_curves[4], "g", label="layers = 4") 
plt.legend(loc = "upper right")
plt.ylabel("training loss")
plt.xlabel("batch/200")
plt.title("Fixed width = 200")
# Out:
# Text(0.5, 1.0, 'Fixed width = 200')

# %%
plt.plot(model_test_curves[0], "r", label="layers = 2")
plt.plot(model_test_curves[3], "b", label="layers = 3")
plt.plot(model_test_curves[4], "g", label="layers = 4") 
plt.legend(loc = "upper right")
plt.ylabel("training loss")
plt.xlabel("batch/200")
plt.title("Fixed width = 200")
# Out:
# Text(0.5, 1.0, 'Fixed width = 200')

# %% [markdown]
# Plot of minimal loss as a function of model size.
#
# ---
# We indeed see that keeping the aspect ratio of the network fixed as we increase the depth substantially improves the performance of the deeper network. However it is still suboptimal to the fixed depth networks, suggesting that the optimal aspect ratio is much smaller than the one I used.

# %%
plt.plot(param_count[:3], min_losses[:3], "b", label="fixed depth")
plt.plot([param_count[0]]+ param_count[3:5], [min_losses[0]] +min_losses[3:5], "r", label= "fixed width")
plt.plot([param_count[0]]+ param_count[5:], [min_losses[0]] +min_losses[5:], "g", label= "fixed ratio")
plt.legend(loc = "lower right")

plt.ylabel("min loss")
plt.xlabel("size")

# %% [markdown]
# # Experiment 2: Smaller models
# -- Here we observe a very clear power law in the network performance! I think this is good evidence for the validity of my previous hypothesis that the larger models were bottlenecked by the training data and we were already too close to the optimal size.

# %%
small_states_wide = [lay.Network_state() for _ in range(5)]
for k, state in enumerate(small_states_wide):
    p= state.parameters
    tr= state.training

    p.d_model=40*(k+1)
    p.d_hid=40*(k+1)
    p.nheads=2
    p.d_key = p.d_model //p.nheads
    p.nlayers=2
    p.network = "encoder"


    tr.batch_size=20
    tr.data_split = 0.8 #fraction of dataset that will be used for training vs validation
    tr.lr = 1.
    tr.seq_length=35
    tr.optimizer = "sgd"

# %%
dataset = dt.Data()
num_epochs = 3

dataset.tokenizer, dataset.train_dataloader, dataset.test_dataloader = dt.process_data(train_iter, txt.library_text_coders, small_states_wide[0], network= "encoder")
for s in small_states_wide:
  s.parameters.ntokens = s.parameters.ntokens_out = len(dataset.tokenizer.vocab)
  s.training.schedule = learning_rate_cosine(factor=5., length = 2300*num_epochs, finalLR=0.5)

# %%
criterion = nn.CrossEntropyLoss()
small_model_train_curves = []
small_model_test_curves =[]
small_min_losses = []
small_param_count = list(map(lay.param_count, small_states_wide))
k=0
for state in small_states_wide:
    #build model
    print(f"***Model {k+1}*** \n Parameters {small_param_count[k]:.1E}\n\n")
    k+=1
    parts = mb.get_transformer_parts(state)
    model = lay.EncoderModel(parts.encoder, parts.linear).to(state.device)
    #train model
    opt, scheduler = mb.get_optimizer(state, model)
    trainer = mt.Model_training(model, opt, criterion, scheduler)
    trainer(epochs=3, data= dataset)
    #record training data
    small_min_losses.append(trainer.min_loss)
    small_model_train_curves.append(trainer.train_loss)
    small_model_test_curves.append(trainer.test_loss)
# Out:
# ***Model 1***
#  Parameters 1.9E+04
#
#
# Batch 200 | lr = 5.490 | time =  0.05 | train_loss  8.82
# Batch 400 | lr = 5.459 | time =  0.06 | train_loss  8.10
# Batch 600 | lr = 5.408 | time =  0.08 | train_loss  7.92
# Batch 800 | lr = 5.337 | time =  0.06 | train_loss  7.84
# Batch 1000 | lr = 5.246 | time =  0.06 | train_loss  7.82
# Batch 1200 | lr = 5.137 | time =  0.06 | train_loss  7.73
# Batch 1400 | lr = 5.010 | time =  0.06 | train_loss  7.62
# Batch 1600 | lr = 4.867 | time =  0.06 | train_loss  7.57
# Batch 1800 | lr = 4.708 | time =  0.06 | train_loss  7.35
# Batch 2000 | lr = 4.535 | time =  0.09 | train_loss  7.29
# Batch 2200 | lr = 4.349 | time =  0.06 | train_loss  7.22
# Epoch: 0 | time: 44.97 | test_loss =  7.07
#
# Batch 200 | lr = 4.007 | time =  0.08 | train_loss  7.03
# Batch 400 | lr = 3.795 | time =  0.06 | train_loss  6.98
# Batch 600 | lr = 3.576 | time =  0.06 | train_loss  6.94
# Batch 800 | lr = 3.352 | time =  0.06 | train_loss  6.88
# Batch 1000 | lr = 3.126 | time =  0.10 | train_loss  6.79
# Batch 1200 | lr = 2.898 | time =  0.05 | train_loss  6.76
# Batch 1400 | lr = 2.672 | time =  0.06 | train_loss  6.72
# Batch 1600 | lr = 2.448 | time =  0.07 | train_loss  6.67
# Batch 1800 | lr = 2.229 | time =  0.06 | train_loss  6.61
# Batch 2000 | lr = 2.016 | time =  0.05 | train_loss  6.57
# Batch 2200 | lr = 1.811 | time =  0.08 | train_loss  6.56
# Epoch: 1 | time: 46.51 | test_loss =  6.53
#
# Batch 200 | lr = 1.484 | time =  0.06 | train_loss  6.49
# Batch 400 | lr = 1.310 | time =  0.06 | train_loss  6.48
# Batch 600 | lr = 1.150 | time =  0.06 | train_loss  6.47
# Batch 800 | lr = 1.004 | time =  0.06 | train_loss  6.45
# Batch 1000 | lr = 0.876 | time =  0.06 | train_loss  6.44
# Batch 1200 | lr = 0.765 | time =  0.07 | train_loss  6.43
# Batch 1400 | lr = 0.672 | time =  0.06 | train_loss  6.43
# Batch 1600 | lr = 0.599 | time =  0.06 | train_loss  6.43
# Batch 1800 | lr = 0.546 | time =  0.07 | train_loss  6.41
# Batch 2000 | lr = 0.513 | time =  0.06 | train_loss  6.43
# Batch 2200 | lr = 0.500 | time =  0.06 | train_loss  6.42
# Epoch: 2 | time: 45.05 | test_loss =  6.45
# ***Model 2***
#  Parameters 7.7E+04
#
#
# Batch 200 | lr = 5.490 | time =  0.06 | train_loss  8.72
# Batch 400 | lr = 5.459 | time =  0.06 | train_loss  7.88
# Batch 600 | lr = 5.408 | time =  0.09 | train_loss  7.58
# Batch 800 | lr = 5.337 | time =  0.06 | train_loss  7.40
# Batch 1000 | lr = 5.246 | time =  0.06 | train_loss  7.28
# Batch 1200 | lr = 5.137 | time =  0.07 | train_loss  7.23
# Batch 1400 | lr = 5.010 | time =  0.06 | train_loss  7.10
# Batch 1600 | lr = 4.867 | time =  0.06 | train_loss  7.04
# Batch 1800 | lr = 4.708 | time =  0.06 | train_loss  6.98
# Batch 2000 | lr = 4.535 | time =  0.08 | train_loss  6.93
# Batch 2200 | lr = 4.349 | time =  0.06 | train_loss  6.84
# Epoch: 0 | time: 48.01 | test_loss =  6.88
#
# Batch 200 | lr = 4.007 | time =  0.09 | train_loss  6.71
# Batch 400 | lr = 3.795 | time =  0.06 | train_loss  6.69
# Batch 600 | lr = 3.576 | time =  0.06 | train_loss  6.62
# Batch 800 | lr = 3.352 | time =  0.09 | train_loss  6.58
# Batch 1000 | lr = 3.126 | time =  0.06 | train_loss  6.55
# Batch 1200 | lr = 2.898 | time =  0.06 | train_loss  6.51
# Batch 1400 | lr = 2.672 | time =  0.08 | train_loss  6.45
# Batch 1600 | lr = 2.448 | time =  0.06 | train_loss  6.40
# Batch 1800 | lr = 2.229 | time =  0.06 | train_loss  6.37
# Batch 2000 | lr = 2.016 | time =  0.06 | train_loss  6.38
# Batch 2200 | lr = 1.811 | time =  0.06 | train_loss  6.34
# Epoch: 1 | time: 48.72 | test_loss =  6.35
#
# Batch 200 | lr = 1.484 | time =  0.06 | train_loss  6.24
# Batch 400 | lr = 1.310 | time =  0.08 | train_loss  6.27
# Batch 600 | lr = 1.150 | time =  0.06 | train_loss  6.26
# Batch 800 | lr = 1.004 | time =  0.06 | train_loss  6.24
# Batch 1000 | lr = 0.876 | time =  0.06 | train_loss  6.22
# Batch 1200 | lr = 0.765 | time =  0.06 | train_loss  6.20
# Batch 1400 | lr = 0.672 | time =  0.06 | train_loss  6.24
# Batch 1600 | lr = 0.599 | time =  0.08 | train_loss  6.21
# Batch 1800 | lr = 0.546 | time =  0.06 | train_loss  6.22
# Batch 2000 | lr = 0.513 | time =  0.06 | train_loss  6.22
# Batch 2200 | lr = 0.500 | time =  0.09 | train_loss  6.21
# Epoch: 2 | time: 48.60 | test_loss =  6.28
# ***Model 3***
#  Parameters 1.7E+05
#
#
# Batch 200 | lr = 5.490 | time =  0.06 | train_loss  8.86
# Batch 400 | lr = 5.459 | time =  0.08 | train_loss  8.06
# Batch 600 | lr = 5.408 | time =  0.06 | train_loss  7.61
# Batch 800 | lr = 5.337 | time =  0.06 | train_loss  7.41
# Batch 1000 | lr = 5.246 | time =  0.08 | train_loss  7.31
# Batch 1200 | lr = 5.137 | time =  0.06 | train_loss  7.19
# Batch 1400 | lr = 5.010 | time =  0.06 | train_loss  7.04
# Batch 1600 | lr = 4.867 | time =  0.08 | train_loss  7.00
# Batch 1800 | lr = 4.708 | time =  0.06 | train_loss  6.91
# Batch 2000 | lr = 4.535 | time =  0.06 | train_loss  6.87
# Batch 2200 | lr = 4.349 | time =  0.08 | train_loss  6.82
# Epoch: 0 | time: 51.05 | test_loss =  6.88
#
# Batch 200 | lr = 4.007 | time =  0.06 | train_loss  6.69
# Batch 400 | lr = 3.795 | time =  0.12 | train_loss  6.63
# Batch 600 | lr = 3.576 | time =  0.06 | train_loss  6.61
# Batch 800 | lr = 3.352 | time =  0.06 | train_loss  6.54
# Batch 1000 | lr = 3.126 | time =  0.08 | train_loss  6.51
# Batch 1200 | lr = 2.898 | time =  0.06 | train_loss  6.45
# Batch 1400 | lr = 2.672 | time =  0.06 | train_loss  6.38
# Batch 1600 | lr = 2.448 | time =  0.08 | train_loss  6.29
# Batch 1800 | lr = 2.229 | time =  0.06 | train_loss  6.33
# Batch 2000 | lr = 2.016 | time =  0.06 | train_loss  6.27
# Batch 2200 | lr = 1.811 | time =  0.09 | train_loss  6.27
# Epoch: 1 | time: 51.17 | test_loss =  6.33
#
# Batch 200 | lr = 1.484 | time =  0.06 | train_loss  6.19
# Batch 400 | lr = 1.310 | time =  0.08 | train_loss  6.17
# Batch 600 | lr = 1.150 | time =  0.06 | train_loss  6.16
# Batch 800 | lr = 1.004 | time =  0.06 | train_loss  6.17
# Batch 1000 | lr = 0.876 | time =  0.08 | train_loss  6.14
# Batch 1200 | lr = 0.765 | time =  0.06 | train_loss  6.16
# Batch 1400 | lr = 0.672 | time =  0.06 | train_loss  6.15
# Batch 1600 | lr = 0.599 | time =  0.08 | train_loss  6.13
# Batch 1800 | lr = 0.546 | time =  0.06 | train_loss  6.15
# Batch 2000 | lr = 0.513 | time =  0.06 | train_loss  6.11
# Batch 2200 | lr = 0.500 | time =  0.12 | train_loss  6.11
# Epoch: 2 | time: 51.11 | test_loss =  6.20
# ***Model 4***
#  Parameters 3.1E+05
#
#
# Batch 200 | lr = 5.490 | time =  0.08 | train_loss  9.02
# Batch 400 | lr = 5.459 | time =  0.09 | train_loss  8.07
# Batch 600 | lr = 5.408 | time =  0.08 | train_loss  7.60
# Batch 800 | lr = 5.337 | time =  0.08 | train_loss  7.44
# Batch 1000 | lr = 5.246 | time =  0.07 | train_loss  7.31
# Batch 1200 | lr = 5.137 | time =  0.07 | train_loss  7.15
# Batch 1400 | lr = 5.010 | time =  0.09 | train_loss  7.13
# Batch 1600 | lr = 4.867 | time =  0.07 | train_loss  6.98
# Batch 1800 | lr = 4.708 | time =  0.07 | train_loss  6.92
# Batch 2000 | lr = 4.535 | time =  0.08 | train_loss  6.85
# Batch 2200 | lr = 4.349 | time =  0.07 | train_loss  6.81
# Epoch: 0 | time: 56.19 | test_loss =  6.59
#
# Batch 200 | lr = 4.007 | time =  0.07 | train_loss  6.65
# Batch 400 | lr = 3.795 | time =  0.07 | train_loss  6.55
# Batch 600 | lr = 3.576 | time =  0.11 | train_loss  6.52
# Batch 800 | lr = 3.352 | time =  0.07 | train_loss  6.46
# Batch 1000 | lr = 3.126 | time =  0.08 | train_loss  6.41
# Batch 1200 | lr = 2.898 | time =  0.08 | train_loss  6.37
# Batch 1400 | lr = 2.672 | time =  0.07 | train_loss  6.34
# Batch 1600 | lr = 2.448 | time =  0.07 | train_loss  6.34
# Batch 1800 | lr = 2.229 | time =  0.08 | train_loss  6.27
# Batch 2000 | lr = 2.016 | time =  0.07 | train_loss  6.25
# Batch 2200 | lr = 1.811 | time =  0.08 | train_loss  6.21
# Epoch: 1 | time: 56.38 | test_loss =  6.23
#
# Batch 200 | lr = 1.484 | time =  0.07 | train_loss  6.15
# Batch 400 | lr = 1.310 | time =  0.07 | train_loss  6.13
# Batch 600 | lr = 1.150 | time =  0.07 | train_loss  6.11
# Batch 800 | lr = 1.004 | time =  0.08 | train_loss  6.09
# Batch 1000 | lr = 0.876 | time =  0.09 | train_loss  6.08
# Batch 1200 | lr = 0.765 | time =  0.07 | train_loss  6.09
# Batch 1400 | lr = 0.672 | time =  0.07 | train_loss  6.06
# Batch 1600 | lr = 0.599 | time =  0.09 | train_loss  6.05
# Batch 1800 | lr = 0.546 | time =  0.08 | train_loss  6.07
# Batch 2000 | lr = 0.513 | time =  0.07 | train_loss  6.08
# Batch 2200 | lr = 0.500 | time =  0.08 | train_loss  6.08
# Epoch: 2 | time: 56.24 | test_loss =  6.15
# ***Model 5***
#  Parameters 4.8E+05
#
#
# Batch 200 | lr = 5.490 | time =  0.09 | train_loss  9.10
# Batch 400 | lr = 5.459 | time =  0.07 | train_loss  7.98
# Batch 600 | lr = 5.408 | time =  0.08 | train_loss  7.55
# Batch 800 | lr = 5.337 | time =  0.09 | train_loss  7.40
# Batch 1000 | lr = 5.246 | time =  0.08 | train_loss  7.27
# Batch 1200 | lr = 5.137 | time =  0.09 | train_loss  7.14
# Batch 1400 | lr = 5.010 | time =  0.08 | train_loss  7.03
# Batch 1600 | lr = 4.867 | time =  0.08 | train_loss  6.97
# Batch 1800 | lr = 4.708 | time =  0.08 | train_loss  6.82
# Batch 2000 | lr = 4.535 | time =  0.08 | train_loss  6.82
# Batch 2200 | lr = 4.349 | time =  0.09 | train_loss  6.74
# Epoch: 0 | time: 59.55 | test_loss =  6.62
#
# Batch 200 | lr = 4.007 | time =  0.07 | train_loss  6.61
# Batch 400 | lr = 3.795 | time =  0.08 | train_loss  6.55
# Batch 600 | lr = 3.576 | time =  0.08 | train_loss  6.52
# Batch 800 | lr = 3.352 | time =  0.08 | train_loss  6.42
# Batch 1000 | lr = 3.126 | time =  0.08 | train_loss  6.38
# Batch 1200 | lr = 2.898 | time =  0.07 | train_loss  6.34
# Batch 1400 | lr = 2.672 | time =  0.10 | train_loss  6.32
# Batch 1600 | lr = 2.448 | time =  0.08 | train_loss  6.30
# Batch 1800 | lr = 2.229 | time =  0.08 | train_loss  6.24
# Batch 2000 | lr = 2.016 | time =  0.08 | train_loss  6.19
# Batch 2200 | lr = 1.811 | time =  0.09 | train_loss  6.19
# Epoch: 1 | time: 58.92 | test_loss =  6.25
#
# Batch 200 | lr = 1.484 | time =  0.08 | train_loss  6.09
# Batch 400 | lr = 1.310 | time =  0.08 | train_loss  6.07
# Batch 600 | lr = 1.150 | time =  0.09 | train_loss  6.11
# Batch 800 | lr = 1.004 | time =  0.08 | train_loss  6.06
# Batch 1000 | lr = 0.876 | time =  0.09 | train_loss  6.03
# Batch 1200 | lr = 0.765 | time =  0.08 | train_loss  6.05
# Batch 1400 | lr = 0.672 | time =  0.08 | train_loss  6.04
# Batch 1600 | lr = 0.599 | time =  0.09 | train_loss  6.04
# Batch 1800 | lr = 0.546 | time =  0.08 | train_loss  6.03
# Batch 2000 | lr = 0.513 | time =  0.08 | train_loss  6.06
# Batch 2200 | lr = 0.500 | time =  0.08 | train_loss  6.00
# Epoch: 2 | time: 58.95 | test_loss =  6.12

# %%
plt.plot(small_model_train_curves[0], "r", label="d_model = 40")
plt.plot(small_model_train_curves[1], "b", label="d_model = 80")
plt.plot(small_model_train_curves[2], "g", label="d_model = 120") 
plt.plot(small_model_train_curves[3], "y", label="d_model = 160") 
plt.plot(small_model_train_curves[4], "p", label="d_model = 200") 
plt.legend(loc = "upper right")
plt.ylabel("training loss")
plt.xlabel("batch/200")
plt.title("Fixed depth = 2 layers")
# Out:
# Text(0.5, 1.0, 'Fixed depth = 2 layers')

# %%
plt.plot(small_model_test_curves[0], "r", label="d_model = 40")
plt.plot(small_model_test_curves[1], "b", label="d_model = 80")
plt.plot(small_model_test_curves[2], "g", label="d_model = 120") 
plt.plot(small_model_test_curves[3], "y", label="d_model = 160") 
plt.plot(small_model_test_curves[4], "p", label="d_model = 200") 
plt.legend(loc = "upper right")
plt.ylabel("test loss")
plt.xlabel("batch/400")
plt.title("Fixed depth = 2 layers")
# Out:
# Text(0.5, 1.0, 'Fixed depth = 2 layers')

# %%
plt.plot(small_param_count, small_min_losses, "b", label="fixed depth")
plt.legend(loc = "upper right")

plt.ylabel("min loss")
plt.xlabel("size")
# Out:
# Text(0.5, 0, 'size')
